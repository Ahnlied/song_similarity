# %%
import os
import re
import pandas as pd

# %%
common_path = '/home/jacs/Documents/DataScience/Personal/'

input_path= 'song_similarity_audio/'

dummy_path = 'song_similarity/'

# As an input there is going to be a list of youtube links that contain audio that can be
# usefull to expand and enrich the database of that particular instrument

# As an input we want a tupple, with the link as first position and instrument as second position

instruments = ['Bass Tuba','French Horn','Trombone','Trumpet in C','Accordion','Cello','Contrabass','Viola','Violin','Alto Saxophone','Bassoon','Clarinet in Bb','Flute','Oboe','Guitar','Electric guitar','Acoustic guitar','Bass guitar','Tapping','Steelpan','Percussion', 'Drum and bass', 'Wind instrument', 'Bowed string instrument']

# %%
final_data_path = common_path + dummy_path + 'data/' #instrument_folder

# %%
for pp in range(1,2):
    if not os.path.exists(final_data_path):
        os.makedirs(final_data_path)
    df_final = pd.DataFrame([])
    instrument = instruments[pp]
#        print(instrument)
    instrument_folder = re.sub(' ','_',str(instrument)).lower()#+'/'
    input_data_path = common_path + input_path+ instrument_folder
#    print(os.listdir(path))
    for file in os.listdir(input_data_path):
        if file == '{}_youtube_database_enrichment.csv'.format(instrument_folder):
            continue
        else:
            df_iteration = pd.read_csv(input_data_path+'/'+file)
            df_final = pd.concat((df_final,df_iteration), axis=0).reset_index(drop=True)
    df_final.to_csv(final_data_path+'{}.csv'.format(instrument_folder))
#    links_audio = list(df_links['youtube_links'])
#        print(instrument,len(links_audio))
#    titles = list(df_links['title'])

# %%
path = '/home/jacs/Documents/DataScience/Personal/song_similarity_audio/'
instrument = 'cello'
os.listdir(path)
# Out:
# ['database_cello_20_peaks_youtube_4829.csv',
#  'database_cello_20_peaks_youtube_5025.csv',
#  'database_cello_20_peaks_youtube_4591.csv',
#  'database_cello_20_peaks_youtube_1638.csv',
#  'database_cello_20_peaks_youtube_3238.csv',
#  'database_cello_20_peaks_youtube_496.csv',
#  'database_cello_20_peaks_youtube_3090.csv',
#  'database_cello_20_peaks_youtube_1278.csv',
#  'database_cello_20_peaks_youtube_997.csv',
#  'database_cello_20_peaks_youtube_3508.csv',
#  'database_cello_20_peaks_youtube_4393.csv',
#  'database_cello_20_peaks_youtube_2906.csv',
#  'database_cello_20_peaks_youtube_3069.csv',
#  'database_cello_20_peaks_youtube_3613.csv',
#  'database_cello_20_peaks_youtube_2340.csv',
#  'database_cello_20_peaks_youtube_189.csv',
#  'database_cello_20_peaks_youtube_61.csv',
#  'database_cello_20_peaks_youtube_1464.csv',
#  'database_cello_20_peaks_youtube_3656.csv',
#  'database_cello_20_peaks_youtube_245.csv',
#  'database_cello_20_peaks_youtube_4937.csv',
#  'database_cello_20_peaks_youtube_244.csv',
#  'database_cello_20_peaks_youtube_2546.csv',
#  'database_cello_20_peaks_youtube_3714.csv',
#  'database_cello_20_peaks_youtube_1288.csv',
#  'database_cello_20_peaks_youtube_3972.csv',
#  'database_cello_20_peaks_youtube_4910.csv',
#  'database_cello_20_peaks_youtube_4688.csv',
#  'database_cello_20_peaks_youtube_3921.csv',
#  'database_cello_20_peaks_youtube_3712.csv',
#  'database_cello_20_peaks_youtube_4994.csv',
#  'database_cello_20_peaks_youtube_298.csv',
#  'database_cello_20_peaks_youtube_1034.csv',
#  'database_cello_20_peaks_youtube_4546.csv',
#  'database_cello_20_peaks_youtube_4209.csv',
#  'database_cello_20_peaks_youtube_4126.csv',
#  'database_cello_20_peaks_youtube_529.csv',
#  'database_cello_20_peaks_youtube_4220.csv',
#  'database_cello_20_peaks_youtube_541.csv',
#  'database_cello_20_peaks_youtube_758.csv',
#  'database_cello_20_peaks_youtube_18.csv',
#  'database_cello_20_peaks_youtube_3799.csv',
#  'database_cello_20_peaks_youtube_3386.csv',
#  'database_cello_20_peaks_youtube_2570.csv',
#  'database_cello_20_peaks_youtube_4673.csv',
#  'database_cello_20_peaks_youtube_1951.csv',
#  'database_cello_20_peaks_youtube_2653.csv',
#  'database_cello_20_peaks_youtube_1699.csv',
#  'database_cello_20_peaks_youtube_4744.csv',
#  'database_cello_20_peaks_youtube_1112.csv',
#  'database_cello_20_peaks_youtube_1194.csv',
#  'database_cello_20_peaks_youtube_600.csv',
#  'database_cello_20_peaks_youtube_3898.csv',
#  'database_cello_20_peaks_youtube_1262.csv',
#  'database_cello_20_peaks_youtube_4381.csv',
#  'database_cello_20_peaks_youtube_3256.csv',
#  'database_cello_20_peaks_youtube_1878.csv',
#  'database_cello_20_peaks_youtube_5026.csv',
#  'database_cello_20_peaks_youtube_706.csv',
#  'database_cello_20_peaks_youtube_4234.csv',
#  'database_cello_20_peaks_youtube_3095.csv',
#  'database_cello_20_peaks_youtube_1467.csv',
#  'database_cello_20_peaks_youtube_3831.csv',
#  'database_cello_20_peaks_youtube_2198.csv',
#  'database_cello_20_peaks_youtube_3815.csv',
#  'database_cello_20_peaks_youtube_2507.csv',
#  'database_cello_20_peaks_youtube_2944.csv',
#  'database_cello_20_peaks_youtube_4806.csv',
#  'database_cello_20_peaks_youtube_2261.csv',
#  'database_cello_20_peaks_youtube_4676.csv',
#  'database_cello_20_peaks_youtube_3192.csv',
#  'database_cello_20_peaks_youtube_2914.csv',
#  'database_cello_20_peaks_youtube_3323.csv',
#  'database_cello_20_peaks_youtube_4657.csv',
#  'database_cello_20_peaks_youtube_3182.csv',
#  'database_cello_20_peaks_youtube_90.csv',
#  'database_cello_20_peaks_youtube_3274.csv',
#  'database_cello_20_peaks_youtube_2243.csv',
#  'database_cello_20_peaks_youtube_733.csv',
#  'database_cello_20_peaks_youtube_2131.csv',
#  'database_cello_20_peaks_youtube_1003.csv',
#  'database_cello_20_peaks_youtube_2308.csv',
#  'database_cello_20_peaks_youtube_819.csv',
#  'database_cello_20_peaks_youtube_1379.csv',
#  'database_cello_20_peaks_youtube_2711.csv',
#  'database_cello_20_peaks_youtube_982.csv',
#  'database_cello_20_peaks_youtube_23.csv',
#  'database_cello_20_peaks_youtube_289.csv',
#  'database_cello_20_peaks_youtube_1500.csv',
#  'database_cello_20_peaks_youtube_749.csv',
#  'database_cello_20_peaks_youtube_283.csv',
#  'database_cello_20_peaks_youtube_2374.csv',
#  'database_cello_20_peaks_youtube_3884.csv',
#  'database_cello_20_peaks_youtube_3215.csv',
#  'database_cello_20_peaks_youtube_1676.csv',
#  'database_cello_20_peaks_youtube_645.csv',
#  'database_cello_20_peaks_youtube_4555.csv',
#  'database_cello_20_peaks_youtube_2809.csv',
#  'database_cello_20_peaks_youtube_4674.csv',
#  'database_cello_20_peaks_youtube_4150.csv',
#  'database_cello_20_peaks_youtube_4073.csv',
#  'database_cello_20_peaks_youtube_3092.csv',
#  'database_cello_20_peaks_youtube_4547.csv',
#  'database_cello_20_peaks_youtube_2435.csv',
#  'database_cello_20_peaks_youtube_3512.csv',
#  'database_cello_20_peaks_youtube_603.csv',
#  'database_cello_20_peaks_youtube_4919.csv',
#  'database_cello_20_peaks_youtube_2692.csv',
#  'database_cello_20_peaks_youtube_1974.csv',
#  'database_cello_20_peaks_youtube_3667.csv',
#  'database_cello_20_peaks_youtube_1839.csv',
#  'database_cello_20_peaks_youtube_1959.csv',
#  'database_cello_20_peaks_youtube_4315.csv',
#  'database_cello_20_peaks_youtube_2612.csv',
#  'database_cello_20_peaks_youtube_1864.csv',
#  'database_cello_20_peaks_youtube_2393.csv',
#  'database_cello_20_peaks_youtube_2065.csv',
#  'database_cello_20_peaks_youtube_2832.csv',
#  'database_cello_20_peaks_youtube_2196.csv',
#  'database_cello_20_peaks_youtube_1981.csv',
#  'database_cello_20_peaks_youtube_1162.csv',
#  'database_cello_20_peaks_youtube_941.csv',
#  'database_cello_20_peaks_youtube_1452.csv',
#  'database_cello_20_peaks_youtube_3535.csv',
#  'database_cello_20_peaks_youtube_3925.csv',
#  'database_cello_20_peaks_youtube_396.csv',
#  'database_cello_20_peaks_youtube_3099.csv',
#  'database_cello_20_peaks_youtube_4609.csv',
#  'database_cello_20_peaks_youtube_160.csv',
#  'database_cello_20_peaks_youtube_1428.csv',
#  'database_cello_20_peaks_youtube_1169.csv',
#  'database_cello_20_peaks_youtube_1685.csv',
#  'database_cello_20_peaks_youtube_1166.csv',
#  'database_cello_20_peaks_youtube_4108.csv',
#  'database_cello_20_peaks_youtube_1517.csv',
#  'database_cello_20_peaks_youtube_4360.csv',
#  'database_cello_20_peaks_youtube_3219.csv',
#  'database_cello_20_peaks_youtube_3048.csv',
#  'database_cello_20_peaks_youtube_4636.csv',
#  'database_cello_20_peaks_youtube_3923.csv',
#  'database_cello_20_peaks_youtube_4148.csv',
#  'database_cello_20_peaks_youtube_3816.csv',
#  'database_cello_20_peaks_youtube_1356.csv',
#  'database_cello_20_peaks_youtube_4977.csv',
#  'database_cello_20_peaks_youtube_3797.csv',
#  'database_cello_20_peaks_youtube_2384.csv',
#  'database_cello_20_peaks_youtube_2867.csv',
#  'database_cello_20_peaks_youtube_3961.csv',
#  'database_cello_20_peaks_youtube_2239.csv',
#  'database_cello_20_peaks_youtube_3200.csv',
#  'database_cello_20_peaks_youtube_1482.csv',
#  'database_cello_20_peaks_youtube_530.csv',
#  'database_cello_20_peaks_youtube_604.csv',
#  'database_cello_20_peaks_youtube_1385.csv',
#  'database_cello_20_peaks_youtube_2235.csv',
#  'database_cello_20_peaks_youtube_150.csv',
#  'database_cello_20_peaks_youtube_4307.csv',
#  'database_cello_20_peaks_youtube_1071.csv',
#  'database_cello_20_peaks_youtube_458.csv',
#  'database_cello_20_peaks_youtube_2673.csv',
#  'database_cello_20_peaks_youtube_1386.csv',
#  'database_cello_20_peaks_youtube_1133.csv',
#  'database_cello_20_peaks_youtube_3232.csv',
#  'database_cello_20_peaks_youtube_1249.csv',
#  'database_cello_20_peaks_youtube_1657.csv',
#  'database_cello_20_peaks_youtube_4001.csv',
#  'database_cello_20_peaks_youtube_3749.csv',
#  'database_cello_20_peaks_youtube_1936.csv',
#  'database_cello_20_peaks_youtube_2496.csv',
#  'database_cello_20_peaks_youtube_3318.csv',
#  'database_cello_20_peaks_youtube_4844.csv',
#  'database_cello_20_peaks_youtube_911.csv',
#  'database_cello_20_peaks_youtube_3057.csv',
#  'database_cello_20_peaks_youtube_4930.csv',
#  'database_cello_20_peaks_youtube_2366.csv',
#  'database_cello_20_peaks_youtube_3343.csv',
#  'database_cello_20_peaks_youtube_727.csv',
#  'database_cello_20_peaks_youtube_1653.csv',
#  'database_cello_20_peaks_youtube_2352.csv',
#  'database_cello_20_peaks_youtube_196.csv',
#  'database_cello_20_peaks_youtube_4069.csv',
#  'database_cello_20_peaks_youtube_2399.csv',
#  'database_cello_20_peaks_youtube_1662.csv',
#  'database_cello_20_peaks_youtube_3852.csv',
#  'database_cello_20_peaks_youtube_1713.csv',
#  'database_cello_20_peaks_youtube_1328.csv',
#  'database_cello_20_peaks_youtube_4862.csv',
#  'database_cello_20_peaks_youtube_673.csv',
#  'database_cello_20_peaks_youtube_4757.csv',
#  'database_cello_20_peaks_youtube_46.csv',
#  'database_cello_20_peaks_youtube_1181.csv',
#  'database_cello_20_peaks_youtube_2111.csv',
#  'database_cello_20_peaks_youtube_4835.csv',
#  'database_cello_20_peaks_youtube_40.csv',
#  'database_cello_20_peaks_youtube_857.csv',
#  'database_cello_20_peaks_youtube_4454.csv',
#  'database_cello_20_peaks_youtube_2307.csv',
#  'database_cello_20_peaks_youtube_4226.csv',
#  'database_cello_20_peaks_youtube_1448.csv',
#  'database_cello_20_peaks_youtube_3583.csv',
#  'database_cello_20_peaks_youtube_3937.csv',
#  'database_cello_20_peaks_youtube_4805.csv',
#  'database_cello_20_peaks_youtube_2002.csv',
#  'database_cello_20_peaks_youtube_4450.csv',
#  'database_cello_20_peaks_youtube_728.csv',
#  'database_cello_20_peaks_youtube_2220.csv',
#  'database_cello_20_peaks_youtube_4798.csv',
#  'database_cello_20_peaks_youtube_4328.csv',
#  'database_cello_20_peaks_youtube_440.csv',
#  'database_cello_20_peaks_youtube_919.csv',
#  'database_cello_20_peaks_youtube_3398.csv',
#  'database_cello_20_peaks_youtube_1928.csv',
#  'database_cello_20_peaks_youtube_419.csv',
#  'database_cello_20_peaks_youtube_297.csv',
#  'database_cello_20_peaks_youtube_2936.csv',
#  'database_cello_20_peaks_youtube_1232.csv',
#  'database_cello_20_peaks_youtube_2640.csv',
#  'database_cello_20_peaks_youtube_4250.csv',
#  'database_cello_20_peaks_youtube_2951.csv',
#  'database_cello_20_peaks_youtube_4091.csv',
#  'database_cello_20_peaks_youtube_1643.csv',
#  'database_cello_20_peaks_youtube_1761.csv',
#  'database_cello_20_peaks_youtube_3260.csv',
#  'database_cello_20_peaks_youtube_1710.csv',
#  'database_cello_20_peaks_youtube_477.csv',
#  'database_cello_20_peaks_youtube_1809.csv',
#  'database_cello_20_peaks_youtube_655.csv',
#  'database_cello_20_peaks_youtube_1004.csv',
#  'database_cello_20_peaks_youtube_1849.csv',
#  'database_cello_20_peaks_youtube_2493.csv',
#  'database_cello_20_peaks_youtube_4883.csv',
#  'database_cello_20_peaks_youtube_4014.csv',
#  'database_cello_20_peaks_youtube_1200.csv',
#  'database_cello_20_peaks_youtube_1511.csv',
#  'database_cello_20_peaks_youtube_2726.csv',
#  'database_cello_20_peaks_youtube_1078.csv',
#  'database_cello_20_peaks_youtube_1948.csv',
#  'database_cello_20_peaks_youtube_3957.csv',
#  'database_cello_20_peaks_youtube_4181.csv',
#  'database_cello_20_peaks_youtube_1235.csv',
#  'database_cello_20_peaks_youtube_4155.csv',
#  'database_cello_20_peaks_youtube_2296.csv',
#  'database_cello_20_peaks_youtube_2591.csv',
#  'database_cello_20_peaks_youtube_1102.csv',
#  'database_cello_20_peaks_youtube_751.csv',
#  'database_cello_20_peaks_youtube_1930.csv',
#  'database_cello_20_peaks_youtube_1851.csv',
#  'database_cello_20_peaks_youtube_778.csv',
#  'database_cello_20_peaks_youtube_2424.csv',
#  'database_cello_20_peaks_youtube_1603.csv',
#  'database_cello_20_peaks_youtube_4352.csv',
#  'database_cello_20_peaks_youtube_2959.csv',
#  'database_cello_20_peaks_youtube_3864.csv',
#  'database_cello_20_peaks_youtube_526.csv',
#  'database_cello_20_peaks_youtube_1835.csv',
#  'database_cello_20_peaks_youtube_587.csv',
#  'database_cello_20_peaks_youtube_1588.csv',
#  'database_cello_20_peaks_youtube_1866.csv',
#  'database_cello_20_peaks_youtube_2844.csv',
#  'database_cello_20_peaks_youtube_2468.csv',
#  'database_cello_20_peaks_youtube_2183.csv',
#  'database_cello_20_peaks_youtube_4572.csv',
#  'database_cello_20_peaks_youtube_1532.csv',
#  'database_cello_20_peaks_youtube_4949.csv',
#  'database_cello_20_peaks_youtube_4446.csv',
#  'database_cello_20_peaks_youtube_2752.csv',
#  'database_cello_20_peaks_youtube_2934.csv',
#  'database_cello_20_peaks_youtube_2479.csv',
#  'database_cello_20_peaks_youtube_620.csv',
#  'database_cello_20_peaks_youtube_3851.csv',
#  'database_cello_20_peaks_youtube_1823.csv',
#  'database_cello_20_peaks_youtube_944.csv',
#  'database_cello_20_peaks_youtube_450.csv',
#  'database_cello_20_peaks_youtube_2568.csv',
#  'database_cello_20_peaks_youtube_4430.csv',
#  'database_cello_20_peaks_youtube_2048.csv',
#  'database_cello_20_peaks_youtube_1581.csv',
#  'database_cello_20_peaks_youtube_3143.csv',
#  'database_cello_20_peaks_youtube_2852.csv',
#  'database_cello_20_peaks_youtube_2550.csv',
#  'database_cello_20_peaks_youtube_4429.csv',
#  'database_cello_20_peaks_youtube_4585.csv',
#  'database_cello_20_peaks_youtube_679.csv',
#  'database_cello_20_peaks_youtube_872.csv',
#  'database_cello_20_peaks_youtube_1600.csv',
#  'database_cello_20_peaks_youtube_3873.csv',
#  'database_cello_20_peaks_youtube_4987.csv',
#  'database_cello_20_peaks_youtube_4218.csv',
#  'database_cello_20_peaks_youtube_30.csv',
#  'database_cello_20_peaks_youtube_1553.csv',
#  'database_cello_20_peaks_youtube_4363.csv',
#  'database_cello_20_peaks_youtube_825.csv',
#  'database_cello_20_peaks_youtube_2241.csv',
#  'database_cello_20_peaks_youtube_3493.csv',
#  'database_cello_20_peaks_youtube_3155.csv',
#  'database_cello_20_peaks_youtube_1505.csv',
#  'database_cello_20_peaks_youtube_45.csv',
#  'database_cello_20_peaks_youtube_7.csv',
#  'database_cello_20_peaks_youtube_4983.csv',
#  'database_cello_20_peaks_youtube_3691.csv',
#  'database_cello_20_peaks_youtube_1239.csv',
#  'database_cello_20_peaks_youtube_3809.csv',
#  'database_cello_20_peaks_youtube_5027.csv',
#  'database_cello_20_peaks_youtube_859.csv',
#  'database_cello_20_peaks_youtube_2055.csv',
#  'database_cello_20_peaks_youtube_2949.csv',
#  'database_cello_20_peaks_youtube_1118.csv',
#  'database_cello_20_peaks_youtube_987.csv',
#  'database_cello_20_peaks_youtube_4832.csv',
#  'database_cello_20_peaks_youtube_2800.csv',
#  'database_cello_20_peaks_youtube_361.csv',
#  'database_cello_20_peaks_youtube_2716.csv',
#  'database_cello_20_peaks_youtube_4574.csv',
#  'database_cello_20_peaks_youtube_2467.csv',
#  'database_cello_20_peaks_youtube_1158.csv',
#  'database_cello_20_peaks_youtube_4388.csv',
#  'database_cello_20_peaks_youtube_4807.csv',
#  'database_cello_20_peaks_youtube_3890.csv',
#  'database_cello_20_peaks_youtube_3441.csv',
#  'database_cello_20_peaks_youtube_1522.csv',
#  'database_cello_20_peaks_youtube_4278.csv',
#  'database_cello_20_peaks_youtube_2012.csv',
#  'database_cello_20_peaks_youtube_113.csv',
#  'database_cello_20_peaks_youtube_2680.csv',
#  'database_cello_20_peaks_youtube_3545.csv',
#  'database_cello_20_peaks_youtube_2400.csv',
#  'database_cello_20_peaks_youtube_3275.csv',
#  'database_cello_20_peaks_youtube_4101.csv',
#  'database_cello_20_peaks_youtube_3202.csv',
#  'database_cello_20_peaks_youtube_1853.csv',
#  'database_cello_20_peaks_youtube_866.csv',
#  'database_cello_20_peaks_youtube_4192.csv',
#  'database_cello_20_peaks_youtube_1368.csv',
#  'database_cello_20_peaks_youtube_2536.csv',
#  'database_cello_20_peaks_youtube_356.csv',
#  'database_cello_20_peaks_youtube_4070.csv',
#  'database_cello_20_peaks_youtube_2452.csv',
#  'database_cello_20_peaks_youtube_2929.csv',
#  'database_cello_20_peaks_youtube_5034.csv',
#  'database_cello_20_peaks_youtube_760.csv',
#  'database_cello_20_peaks_youtube_1795.csv',
#  'database_cello_20_peaks_youtube_1791.csv',
#  'database_cello_20_peaks_youtube_2765.csv',
#  'database_cello_20_peaks_youtube_1528.csv',
#  'database_cello_20_peaks_youtube_4492.csv',
#  'database_cello_20_peaks_youtube_163.csv',
#  'database_cello_20_peaks_youtube_4641.csv',
#  'database_cello_20_peaks_youtube_57.csv',
#  'database_cello_20_peaks_youtube_3987.csv',
#  'database_cello_20_peaks_youtube_4842.csv',
#  'database_cello_20_peaks_youtube_4166.csv',
#  'database_cello_20_peaks_youtube_172.csv',
#  'database_cello_20_peaks_youtube_2843.csv',
#  'database_cello_20_peaks_youtube_98.csv',
#  'database_cello_20_peaks_youtube_4361.csv',
#  'database_cello_20_peaks_youtube_892.csv',
#  'database_cello_20_peaks_youtube_2879.csv',
#  'database_cello_20_peaks_youtube_523.csv',
#  'database_cello_20_peaks_youtube_3392.csv',
#  'database_cello_20_peaks_youtube_3780.csv',
#  'database_cello_20_peaks_youtube_1153.csv',
#  'database_cello_20_peaks_youtube_2565.csv',
#  'database_cello_20_peaks_youtube_2810.csv',
#  'database_cello_20_peaks_youtube_2738.csv',
#  'database_cello_20_peaks_youtube_4174.csv',
#  'database_cello_20_peaks_youtube_3014.csv',
#  'database_cello_20_peaks_youtube_678.csv',
#  'database_cello_20_peaks_youtube_2528.csv',
#  'database_cello_20_peaks_youtube_299.csv',
#  'database_cello_20_peaks_youtube_3767.csv',
#  'database_cello_20_peaks_youtube_712.csv',
#  'database_cello_20_peaks_youtube_4497.csv',
#  'database_cello_20_peaks_youtube_2811.csv',
#  'database_cello_20_peaks_youtube_2143.csv',
#  'database_cello_20_peaks_youtube_4846.csv',
#  'database_cello_20_peaks_youtube_4761.csv',
#  'database_cello_20_peaks_youtube_2838.csv',
#  'database_cello_20_peaks_youtube_4420.csv',
#  'database_cello_20_peaks_youtube_644.csv',
#  'database_cello_20_peaks_youtube_338.csv',
#  'database_cello_20_peaks_youtube_3642.csv',
#  'database_cello_20_peaks_youtube_901.csv',
#  'database_cello_20_peaks_youtube_4927.csv',
#  'database_cello_20_peaks_youtube_1720.csv',
#  'database_cello_20_peaks_youtube_1175.csv',
#  'database_cello_20_peaks_youtube_3838.csv',
#  'database_cello_20_peaks_youtube_2335.csv',
#  'database_cello_20_peaks_youtube_4896.csv',
#  'database_cello_20_peaks_youtube_432.csv',
#  'database_cello_20_peaks_youtube_865.csv',
#  'database_cello_20_peaks_youtube_2167.csv',
#  'database_cello_20_peaks_youtube_4167.csv',
#  'database_cello_20_peaks_youtube_4461.csv',
#  'database_cello_20_peaks_youtube_1645.csv',
#  'database_cello_20_peaks_youtube_4465.csv',
#  'database_cello_20_peaks_youtube_1359.csv',
#  'database_cello_20_peaks_youtube_563.csv',
#  'database_cello_20_peaks_youtube_4313.csv',
#  'database_cello_20_peaks_youtube_2339.csv',
#  'database_cello_20_peaks_youtube_1768.csv',
#  'database_cello_20_peaks_youtube_4480.csv',
#  'database_cello_20_peaks_youtube_875.csv',
#  'database_cello_20_peaks_youtube_1863.csv',
#  'database_cello_20_peaks_youtube_37.csv',
#  'database_cello_20_peaks_youtube_832.csv',
#  'database_cello_20_peaks_youtube_4134.csv',
#  'database_cello_20_peaks_youtube_1991.csv',
#  'database_cello_20_peaks_youtube_4527.csv',
#  'database_cello_20_peaks_youtube_4453.csv',
#  'database_cello_20_peaks_youtube_1712.csv',
#  'database_cello_20_peaks_youtube_2169.csv',
#  'database_cello_20_peaks_youtube_2922.csv',
#  'database_cello_20_peaks_youtube_2551.csv',
#  'database_cello_20_peaks_youtube_1024.csv',
#  'database_cello_20_peaks_youtube_4190.csv',
#  'database_cello_20_peaks_youtube_1629.csv',
#  'database_cello_20_peaks_youtube_1440.csv',
#  'database_cello_20_peaks_youtube_4237.csv',
#  'database_cello_20_peaks_youtube_1293.csv',
#  'database_cello_20_peaks_youtube_240.csv',
#  'database_cello_20_peaks_youtube_218.csv',
#  'database_cello_20_peaks_youtube_65.csv',
#  'database_cello_20_peaks_youtube_376.csv',
#  'database_cello_20_peaks_youtube_4039.csv',
#  'database_cello_20_peaks_youtube_1311.csv',
#  'database_cello_20_peaks_youtube_754.csv',
#  'database_cello_20_peaks_youtube_2788.csv',
#  'database_cello_20_peaks_youtube_48.csv',
#  'database_cello_20_peaks_youtube_212.csv',
#  'database_cello_20_peaks_youtube_164.csv',
#  'database_cello_20_peaks_youtube_3027.csv',
#  'database_cello_20_peaks_youtube_254.csv',
#  'database_cello_20_peaks_youtube_568.csv',
#  'database_cello_20_peaks_youtube_3844.csv',
#  'database_cello_20_peaks_youtube_1994.csv',
#  'database_cello_20_peaks_youtube_768.csv',
#  'database_cello_20_peaks_youtube_2313.csv',
#  'database_cello_20_peaks_youtube_4558.csv',
#  'database_cello_20_peaks_youtube_4528.csv',
#  'database_cello_20_peaks_youtube_3742.csv',
#  'database_cello_20_peaks_youtube_1284.csv',
#  'database_cello_20_peaks_youtube_599.csv',
#  'database_cello_20_peaks_youtube_2123.csv',
#  'database_cello_20_peaks_youtube_1189.csv',
#  'database_cello_20_peaks_youtube_4887.csv',
#  'database_cello_20_peaks_youtube_933.csv',
#  'database_cello_20_peaks_youtube_845.csv',
#  'database_cello_20_peaks_youtube_1281.csv',
#  'database_cello_20_peaks_youtube_576.csv',
#  'database_cello_20_peaks_youtube_345.csv',
#  'database_cello_20_peaks_youtube_1117.csv',
#  'database_cello_20_peaks_youtube_2271.csv',
#  'database_cello_20_peaks_youtube_4561.csv',
#  'database_cello_20_peaks_youtube_1209.csv',
#  'database_cello_20_peaks_youtube_4326.csv',
#  'database_cello_20_peaks_youtube_801.csv',
#  'database_cello_20_peaks_youtube_3699.csv',
#  'database_cello_20_peaks_youtube_135.csv',
#  'database_cello_20_peaks_youtube_4921.csv',
#  'database_cello_20_peaks_youtube_3728.csv',
#  'database_cello_20_peaks_youtube_1896.csv',
#  'database_cello_20_peaks_youtube_4086.csv',
#  'database_cello_20_peaks_youtube_3020.csv',
#  'database_cello_20_peaks_youtube_15.csv',
#  'database_cello_20_peaks_youtube_3378.csv',
#  'database_cello_20_peaks_youtube_4354.csv',
#  'database_cello_20_peaks_youtube_5039.csv',
#  'database_cello_20_peaks_youtube_43.csv',
#  'database_cello_20_peaks_youtube_977.csv',
#  'database_cello_20_peaks_youtube_1441.csv',
#  'database_cello_20_peaks_youtube_4032.csv',
#  'database_cello_20_peaks_youtube_1397.csv',
#  'database_cello_20_peaks_youtube_3571.csv',
#  'database_cello_20_peaks_youtube_1433.csv',
#  'database_cello_20_peaks_youtube_2962.csv',
#  'database_cello_20_peaks_youtube_1862.csv',
#  'database_cello_20_peaks_youtube_2381.csv',
#  'database_cello_20_peaks_youtube_2827.csv',
#  'database_cello_20_peaks_youtube_465.csv',
#  'database_cello_20_peaks_youtube_2506.csv',
#  'database_cello_20_peaks_youtube_4459.csv',
#  'database_cello_20_peaks_youtube_3931.csv',
#  'database_cello_20_peaks_youtube_2753.csv',
#  'database_cello_20_peaks_youtube_629.csv',
#  'database_cello_20_peaks_youtube_4727.csv',
#  'database_cello_20_peaks_youtube_2011.csv',
#  'database_cello_20_peaks_youtube_4703.csv',
#  'database_cello_20_peaks_youtube_1808.csv',
#  'database_cello_20_peaks_youtube_180.csv',
#  'database_cello_20_peaks_youtube_1990.csv',
#  'database_cello_20_peaks_youtube_4357.csv',
#  'database_cello_20_peaks_youtube_2454.csv',
#  'database_cello_20_peaks_youtube_2763.csv',
#  'database_cello_20_peaks_youtube_4537.csv',
#  'database_cello_20_peaks_youtube_4811.csv',
#  'database_cello_20_peaks_youtube_932.csv',
#  'database_cello_20_peaks_youtube_4956.csv',
#  'database_cello_20_peaks_youtube_853.csv',
#  'database_cello_20_peaks_youtube_3120.csv',
#  'database_cello_20_peaks_youtube_3567.csv',
#  'database_cello_20_peaks_youtube_170.csv',
#  'database_cello_20_peaks_youtube_920.csv',
#  'database_cello_20_peaks_youtube_17.csv',
#  'database_cello_20_peaks_youtube_4255.csv',
#  'database_cello_20_peaks_youtube_1431.csv',
#  'database_cello_20_peaks_youtube_2067.csv',
#  'database_cello_20_peaks_youtube_1781.csv',
#  'database_cello_20_peaks_youtube_1170.csv',
#  'database_cello_20_peaks_youtube_1323.csv',
#  'database_cello_20_peaks_youtube_1861.csv',
#  'database_cello_20_peaks_youtube_4341.csv',
#  'database_cello_20_peaks_youtube_1628.csv',
#  'database_cello_20_peaks_youtube_989.csv',
#  'database_cello_20_peaks_youtube_2104.csv',
#  'database_cello_20_peaks_youtube_475.csv',
#  'database_cello_20_peaks_youtube_967.csv',
#  'database_cello_20_peaks_youtube_2445.csv',
#  'database_cello_20_peaks_youtube_3896.csv',
#  'database_cello_20_peaks_youtube_3570.csv',
#  'database_cello_20_peaks_youtube_3222.csv',
#  'database_cello_20_peaks_youtube_4322.csv',
#  'database_cello_20_peaks_youtube_1665.csv',
#  'database_cello_20_peaks_youtube_3857.csv',
#  'database_cello_20_peaks_youtube_261.csv',
#  'database_cello_20_peaks_youtube_2689.csv',
#  'database_cello_20_peaks_youtube_4252.csv',
#  'database_cello_20_peaks_youtube_2133.csv',
#  'database_cello_20_peaks_youtube_4570.csv',
#  'database_cello_20_peaks_youtube_814.csv',
#  'database_cello_20_peaks_youtube_3645.csv',
#  'database_cello_20_peaks_youtube_1942.csv',
#  'database_cello_20_peaks_youtube_2061.csv',
#  'database_cello_20_peaks_youtube_913.csv',
#  'database_cello_20_peaks_youtube_2105.csv',
#  'database_cello_20_peaks_youtube_1171.csv',
#  'database_cello_20_peaks_youtube_4207.csv',
#  'database_cello_20_peaks_youtube_1806.csv',
#  'database_cello_20_peaks_youtube_963.csv',
#  'database_cello_20_peaks_youtube_2889.csv',
#  'database_cello_20_peaks_youtube_3782.csv',
#  'database_cello_20_peaks_youtube_4414.csv',
#  'database_cello_20_peaks_youtube_4588.csv',
#  'database_cello_20_peaks_youtube_621.csv',
#  'database_cello_20_peaks_youtube_1308.csv',
#  'database_cello_20_peaks_youtube_4669.csv',
#  'database_cello_20_peaks_youtube_4869.csv',
#  'database_cello_20_peaks_youtube_2327.csv',
#  'database_cello_20_peaks_youtube_4945.csv',
#  'database_cello_20_peaks_youtube_3661.csv',
#  'database_cello_20_peaks_youtube_4395.csv',
#  'database_cello_20_peaks_youtube_322.csv',
#  'database_cello_20_peaks_youtube_1797.csv',
#  'database_cello_20_peaks_youtube_1833.csv',
#  'database_cello_20_peaks_youtube_4498.csv',
#  'database_cello_20_peaks_youtube_3463.csv',
#  'database_cello_20_peaks_youtube_1975.csv',
#  'database_cello_20_peaks_youtube_3752.csv',
#  'database_cello_20_peaks_youtube_4191.csv',
#  'database_cello_20_peaks_youtube_4735.csv',
#  'database_cello_20_peaks_youtube_473.csv',
#  'database_cello_20_peaks_youtube_1130.csv',
#  'database_cello_20_peaks_youtube_1541.csv',
#  'database_cello_20_peaks_youtube_3011.csv',
#  'database_cello_20_peaks_youtube_783.csv',
#  'database_cello_20_peaks_youtube_863.csv',
#  'database_cello_20_peaks_youtube_1422.csv',
#  'database_cello_20_peaks_youtube_4736.csv',
#  'database_cello_20_peaks_youtube_1964.csv',
#  'database_cello_20_peaks_youtube_1757.csv',
#  'database_cello_20_peaks_youtube_3076.csv',
#  'database_cello_20_peaks_youtube_4248.csv',
#  'database_cello_20_peaks_youtube_1697.csv',
#  'database_cello_20_peaks_youtube_2444.csv',
#  'database_cello_20_peaks_youtube_102.csv',
#  'database_cello_20_peaks_youtube_840.csv',
#  'database_cello_20_peaks_youtube_2436.csv',
#  'database_cello_20_peaks_youtube_4212.csv',
#  'database_cello_20_peaks_youtube_4597.csv',
#  'database_cello_20_peaks_youtube_1811.csv',
#  'database_cello_20_peaks_youtube_92.csv',
#  'database_cello_20_peaks_youtube_1736.csv',
#  'database_cello_20_peaks_youtube_739.csv',
#  'database_cello_20_peaks_youtube_773.csv',
#  'database_cello_20_peaks_youtube_851.csv',
#  'database_cello_20_peaks_youtube_1191.csv',
#  'database_cello_20_peaks_youtube_3234.csv',
#  'database_cello_20_peaks_youtube_1322.csv',
#  'database_cello_20_peaks_youtube_820.csv',
#  'database_cello_20_peaks_youtube_2747.csv',
#  'database_cello_20_peaks_youtube_123.csv',
#  'database_cello_20_peaks_youtube_4979.csv',
#  'database_cello_20_peaks_youtube_4953.csv',
#  'database_cello_20_peaks_youtube_3965.csv',
#  'database_cello_20_peaks_youtube_2508.csv',
#  'database_cello_20_peaks_youtube_3546.csv',
#  'database_cello_20_peaks_youtube_4162.csv',
#  'database_cello_20_peaks_youtube_1641.csv',
#  'database_cello_20_peaks_youtube_1031.csv',
#  'database_cello_20_peaks_youtube_2047.csv',
#  'database_cello_20_peaks_youtube_634.csv',
#  'database_cello_20_peaks_youtube_4296.csv',
#  'database_cello_20_peaks_youtube_3576.csv',
#  'database_cello_20_peaks_youtube_1463.csv',
#  'database_cello_20_peaks_youtube_1890.csv',
#  'database_cello_20_peaks_youtube_3039.csv',
#  'database_cello_20_peaks_youtube_4325.csv',
#  'database_cello_20_peaks_youtube_1495.csv',
#  'database_cello_20_peaks_youtube_2620.csv',
#  'database_cello_20_peaks_youtube_2286.csv',
#  'database_cello_20_peaks_youtube_1395.csv',
#  'database_cello_20_peaks_youtube_1447.csv',
#  'database_cello_20_peaks_youtube_5037.csv',
#  'database_cello_20_peaks_youtube_2651.csv',
#  'database_cello_20_peaks_youtube_1772.csv',
#  'database_cello_20_peaks_youtube_3344.csv',
#  'database_cello_20_peaks_youtube_4223.csv',
#  'database_cello_20_peaks_youtube_986.csv',
#  'database_cello_20_peaks_youtube_3430.csv',
#  'database_cello_20_peaks_youtube_838.csv',
#  'database_cello_20_peaks_youtube_500.csv',
#  'database_cello_20_peaks_youtube_2432.csv',
#  'database_cello_20_peaks_youtube_2141.csv',
#  'database_cello_20_peaks_youtube_2069.csv',
#  'database_cello_20_peaks_youtube_981.csv',
#  'database_cello_20_peaks_youtube_4550.csv',
#  'database_cello_20_peaks_youtube_3653.csv',
#  'database_cello_20_peaks_youtube_1213.csv',
#  'database_cello_20_peaks_youtube_2158.csv',
#  'database_cello_20_peaks_youtube_4864.csv',
#  'database_cello_20_peaks_youtube_1925.csv',
#  'database_cello_20_peaks_youtube_877.csv',
#  'database_cello_20_peaks_youtube_2100.csv',
#  'database_cello_20_peaks_youtube_1617.csv',
#  'database_cello_20_peaks_youtube_1746.csv',
#  'database_cello_20_peaks_youtube_4232.csv',
#  'database_cello_20_peaks_youtube_1104.csv',
#  'database_cello_20_peaks_youtube_1084.csv',
#  'database_cello_20_peaks_youtube_1570.csv',
#  'database_cello_20_peaks_youtube_499.csv',
#  'database_cello_20_peaks_youtube_2020.csv',
#  'database_cello_20_peaks_youtube_2954.csv',
#  'database_cello_20_peaks_youtube_3651.csv',
#  'database_cello_20_peaks_youtube_1095.csv',
#  'database_cello_20_peaks_youtube_2458.csv',
#  'database_cello_20_peaks_youtube_4958.csv',
#  'database_cello_20_peaks_youtube_1550.csv',
#  'database_cello_20_peaks_youtube_2446.csv',
#  'database_cello_20_peaks_youtube_701.csv',
#  'database_cello_20_peaks_youtube_1894.csv',
#  'database_cello_20_peaks_youtube_1083.csv',
#  'database_cello_20_peaks_youtube_1387.csv',
#  'database_cello_20_peaks_youtube_1674.csv',
#  'database_cello_20_peaks_youtube_4370.csv',
#  'database_cello_20_peaks_youtube_692.csv',
#  'database_cello_20_peaks_youtube_4389.csv',
#  'database_cello_20_peaks_youtube_3743.csv',
#  'database_cello_20_peaks_youtube_4650.csv',
#  'database_cello_20_peaks_youtube_793.csv',
#  'database_cello_20_peaks_youtube_2598.csv',
#  'database_cello_20_peaks_youtube_3531.csv',
#  'database_cello_20_peaks_youtube_1723.csv',
#  'database_cello_20_peaks_youtube_3096.csv',
#  'database_cello_20_peaks_youtube_939.csv',
#  'database_cello_20_peaks_youtube_2783.csv',
#  'database_cello_20_peaks_youtube_2543.csv',
#  'database_cello_20_peaks_youtube_2826.csv',
#  'database_cello_20_peaks_youtube_985.csv',
#  'database_cello_20_peaks_youtube_2572.csv',
#  'database_cello_20_peaks_youtube_890.csv',
#  'database_cello_20_peaks_youtube_4902.csv',
#  'database_cello_20_peaks_youtube_4587.csv',
#  'database_cello_20_peaks_youtube_383.csv',
#  'database_cello_20_peaks_youtube_3062.csv',
#  'database_cello_20_peaks_youtube_2257.csv',
#  'database_cello_20_peaks_youtube_2098.csv',
#  'database_cello_20_peaks_youtube_107.csv',
#  'database_cello_20_peaks_youtube_1174.csv',
#  'database_cello_20_peaks_youtube_437.csv',
#  'database_cello_20_peaks_youtube_2839.csv',
#  'database_cello_20_peaks_youtube_187.csv',
#  'database_cello_20_peaks_youtube_928.csv',
#  'database_cello_20_peaks_youtube_2318.csv',
#  'database_cello_20_peaks_youtube_3704.csv',
#  'database_cello_20_peaks_youtube_3178.csv',
#  'database_cello_20_peaks_youtube_1.csv',
#  'database_cello_20_peaks_youtube_4441.csv',
#  'database_cello_20_peaks_youtube_3435.csv',
#  'database_cello_20_peaks_youtube_662.csv',
#  'database_cello_20_peaks_youtube_4089.csv',
#  'database_cello_20_peaks_youtube_2728.csv',
#  'database_cello_20_peaks_youtube_3140.csv',
#  'database_cello_20_peaks_youtube_1722.csv',
#  'database_cello_20_peaks_youtube_2297.csv',
#  'database_cello_20_peaks_youtube_3958.csv',
#  'database_cello_20_peaks_youtube_4645.csv',
#  'database_cello_20_peaks_youtube_3920.csv',
#  'database_cello_20_peaks_youtube_1391.csv',
#  'database_cello_20_peaks_youtube_3261.csv',
#  'database_cello_20_peaks_youtube_1621.csv',
#  'database_cello_20_peaks_youtube_1301.csv',
#  'database_cello_20_peaks_youtube_3419.csv',
#  'database_cello_20_peaks_youtube_4742.csv',
#  'database_cello_20_peaks_youtube_1616.csv',
#  'database_cello_20_peaks_youtube_1373.csv',
#  'database_cello_20_peaks_youtube_3461.csv',
#  'database_cello_20_peaks_youtube_2611.csv',
#  'database_cello_20_peaks_youtube_3315.csv',
#  'database_cello_20_peaks_youtube_700.csv',
#  'database_cello_20_peaks_youtube_1488.csv',
#  'database_cello_20_peaks_youtube_663.csv',
#  'database_cello_20_peaks_youtube_1289.csv',
#  'database_cello_20_peaks_youtube_5028.csv',
#  'database_cello_20_peaks_youtube_3585.csv',
#  'database_cello_20_peaks_youtube_3511.csv',
#  'database_cello_20_peaks_youtube_209.csv',
#  'database_cello_20_peaks_youtube_2643.csv',
#  'database_cello_20_peaks_youtube_4144.csv',
#  'database_cello_20_peaks_youtube_3250.csv',
#  'database_cello_20_peaks_youtube_1274.csv',
#  'database_cello_20_peaks_youtube_4963.csv',
#  'database_cello_20_peaks_youtube_909.csv',
#  'database_cello_20_peaks_youtube_4873.csv',
#  'database_cello_20_peaks_youtube_317.csv',
#  'database_cello_20_peaks_youtube_3276.csv',
#  'database_cello_20_peaks_youtube_745.csv',
#  'database_cello_20_peaks_youtube_1015.csv',
#  'database_cello_20_peaks_youtube_110.csv',
#  'database_cello_20_peaks_youtube_1008.csv',
#  'database_cello_20_peaks_youtube_724.csv',
#  'database_cello_20_peaks_youtube_3128.csv',
#  'database_cello_20_peaks_youtube_251.csv',
#  'database_cello_20_peaks_youtube_3407.csv',
#  'database_cello_20_peaks_youtube_756.csv',
#  'database_cello_20_peaks_youtube_3337.csv',
#  'database_cello_20_peaks_youtube_4474.csv',
#  'database_cello_20_peaks_youtube_2301.csv',
#  'database_cello_20_peaks_youtube_4085.csv',
#  'database_cello_20_peaks_youtube_1814.csv',
#  'database_cello_20_peaks_youtube_4628.csv',
#  'database_cello_20_peaks_youtube_280.csv',
#  'database_cello_20_peaks_youtube_1029.csv',
#  'database_cello_20_peaks_youtube_867.csv',
#  'database_cello_20_peaks_youtube_4128.csv',
#  'database_cello_20_peaks_youtube_2149.csv',
#  'database_cello_20_peaks_youtube_4383.csv',
#  'database_cello_20_peaks_youtube_3335.csv',
#  'database_cello_20_peaks_youtube_486.csv',
#  'database_cello_20_peaks_youtube_2522.csv',
#  'database_cello_20_peaks_youtube_1360.csv',
#  'database_cello_20_peaks_youtube_3943.csv',
#  'database_cello_20_peaks_youtube_534.csv',
#  'database_cello_20_peaks_youtube_2205.csv',
#  'database_cello_20_peaks_youtube_4310.csv',
#  'database_cello_20_peaks_youtube_553.csv',
#  'database_cello_20_peaks_youtube_3772.csv',
#  'database_cello_20_peaks_youtube_4769.csv',
#  'database_cello_20_peaks_youtube_2210.csv',
#  'database_cello_20_peaks_youtube_4131.csv',
#  'database_cello_20_peaks_youtube_4833.csv',
#  'database_cello_20_peaks_youtube_3660.csv',
#  'database_cello_20_peaks_youtube_1231.csv',
#  'database_cello_20_peaks_youtube_372.csv',
#  'database_cello_20_peaks_youtube_3770.csv',
#  'database_cello_20_peaks_youtube_2558.csv',
#  'database_cello_20_peaks_youtube_3900.csv',
#  'database_cello_20_peaks_youtube_459.csv',
#  'database_cello_20_peaks_youtube_2556.csv',
#  'database_cello_20_peaks_youtube_3507.csv',
#  'database_cello_20_peaks_youtube_1838.csv',
#  'database_cello_20_peaks_youtube_2822.csv',
#  'database_cello_20_peaks_youtube_114.csv',
#  'database_cello_20_peaks_youtube_4042.csv',
#  'database_cello_20_peaks_youtube_3803.csv',
#  'database_cello_20_peaks_youtube_4311.csv',
#  'database_cello_20_peaks_youtube_1043.csv',
#  'database_cello_20_peaks_youtube_2413.csv',
#  'database_cello_20_peaks_youtube_4373.csv',
#  'database_cello_20_peaks_youtube_1136.csv',
#  'database_cello_20_peaks_youtube_24.csv',
#  'database_cello_20_peaks_youtube_1914.csv',
#  'database_cello_20_peaks_youtube_3792.csv',
#  'database_cello_20_peaks_youtube_1350.csv',
#  'database_cello_20_peaks_youtube_4314.csv',
#  'database_cello_20_peaks_youtube_4484.csv',
#  'database_cello_20_peaks_youtube_4540.csv',
#  'database_cello_20_peaks_youtube_4112.csv',
#  'database_cello_20_peaks_youtube_2580.csv',
#  'database_cello_20_peaks_youtube_31.csv',
#  'database_cello_20_peaks_youtube_2010.csv',
#  'database_cello_20_peaks_youtube_1983.csv',
#  'database_cello_20_peaks_youtube_2856.csv',
#  'database_cello_20_peaks_youtube_3603.csv',
#  'database_cello_20_peaks_youtube_1186.csv',
#  'database_cello_20_peaks_youtube_4152.csv',
#  'database_cello_20_peaks_youtube_4606.csv',
#  'database_cello_20_peaks_youtube_2053.csv',
#  'database_cello_20_peaks_youtube_1549.csv',
#  'database_cello_20_peaks_youtube_4172.csv',
#  'database_cello_20_peaks_youtube_4034.csv',
#  'database_cello_20_peaks_youtube_151.csv',
#  'database_cello_20_peaks_youtube_671.csv',
#  'database_cello_20_peaks_youtube_4201.csv',
#  'database_cello_20_peaks_youtube_4079.csv',
#  'database_cello_20_peaks_youtube_2120.csv',
#  'database_cello_20_peaks_youtube_3210.csv',
#  'database_cello_20_peaks_youtube_1434.csv',
#  'database_cello_20_peaks_youtube_4247.csv',
#  'database_cello_20_peaks_youtube_3559.csv',
#  'database_cello_20_peaks_youtube_4399.csv',
#  'database_cello_20_peaks_youtube_4406.csv',
#  'database_cello_20_peaks_youtube_1261.csv',
#  'database_cello_20_peaks_youtube_3954.csv',
#  'database_cello_20_peaks_youtube_3618.csv',
#  'database_cello_20_peaks_youtube_3730.csv',
#  'database_cello_20_peaks_youtube_1040.csv',
#  'database_cello_20_peaks_youtube_4051.csv',
#  'database_cello_20_peaks_youtube_4476.csv',
#  'database_cello_20_peaks_youtube_2660.csv',
#  'database_cello_20_peaks_youtube_4292.csv',
#  'database_cello_20_peaks_youtube_409.csv',
#  'database_cello_20_peaks_youtube_4701.csv',
#  'database_cello_20_peaks_youtube_846.csv',
#  'database_cello_20_peaks_youtube_2641.csv',
#  'database_cello_20_peaks_youtube_4928.csv',
#  'database_cello_20_peaks_youtube_1396.csv',
#  'database_cello_20_peaks_youtube_1973.csv',
#  'database_cello_20_peaks_youtube_902.csv',
#  'database_cello_20_peaks_youtube_1834.csv',
#  'database_cello_20_peaks_youtube_1073.csv',
#  'database_cello_20_peaks_youtube_999.csv',
#  'database_cello_20_peaks_youtube_3469.csv',
#  'database_cello_20_peaks_youtube_811.csv',
#  'database_cello_20_peaks_youtube_672.csv',
#  'database_cello_20_peaks_youtube_4812.csv',
#  'database_cello_20_peaks_youtube_968.csv',
#  'database_cello_20_peaks_youtube_1703.csv',
#  'database_cello_20_peaks_youtube_3771.csv',
#  'database_cello_20_peaks_youtube_3129.csv',
#  'database_cello_20_peaks_youtube_2091.csv',
#  'database_cello_20_peaks_youtube_3630.csv',
#  'database_cello_20_peaks_youtube_3966.csv',
#  'database_cello_20_peaks_youtube_470.csv',
#  'database_cello_20_peaks_youtube_2244.csv',
#  'database_cello_20_peaks_youtube_1251.csv',
#  'database_cello_20_peaks_youtube_886.csv',
#  'database_cello_20_peaks_youtube_3701.csv',
#  'database_cello_20_peaks_youtube_1049.csv',
#  'database_cello_20_peaks_youtube_2089.csv',
#  'database_cello_20_peaks_youtube_1626.csv',
#  'database_cello_20_peaks_youtube_3194.csv',
#  'database_cello_20_peaks_youtube_2062.csv',
#  'database_cello_20_peaks_youtube_2026.csv',
#  'database_cello_20_peaks_youtube_3719.csv',
#  'database_cello_20_peaks_youtube_1858.csv',
#  'database_cello_20_peaks_youtube_4346.csv',
#  'database_cello_20_peaks_youtube_1316.csv',
#  'database_cello_20_peaks_youtube_2631.csv',
#  'database_cello_20_peaks_youtube_3737.csv',
#  'database_cello_20_peaks_youtube_2251.csv',
#  'database_cello_20_peaks_youtube_1724.csv',
#  'database_cello_20_peaks_youtube_255.csv',
#  'database_cello_20_peaks_youtube_538.csv',
#  'database_cello_20_peaks_youtube_3185.csv',
#  'database_cello_20_peaks_youtube_518.csv',
#  'database_cello_20_peaks_youtube_736.csv',
#  'database_cello_20_peaks_youtube_2760.csv',
#  'database_cello_20_peaks_youtube_4955.csv',
#  'database_cello_20_peaks_youtube_3464.csv',
#  'database_cello_20_peaks_youtube_337.csv',
#  'database_cello_20_peaks_youtube_1035.csv',
#  'database_cello_20_peaks_youtube_1915.csv',
#  'database_cello_20_peaks_youtube_1351.csv',
#  'database_cello_20_peaks_youtube_3608.csv',
#  'database_cello_20_peaks_youtube_69.csv',
#  'database_cello_20_peaks_youtube_3779.csv',
#  'database_cello_20_peaks_youtube_2470.csv',
#  'database_cello_20_peaks_youtube_256.csv',
#  'database_cello_20_peaks_youtube_1343.csv',
#  'database_cello_20_peaks_youtube_2181.csv',
#  'database_cello_20_peaks_youtube_2529.csv',
#  'database_cello_20_peaks_youtube_4178.csv',
#  'database_cello_20_peaks_youtube_3282.csv',
#  'database_cello_20_peaks_youtube_5015.csv',
#  'database_cello_20_peaks_youtube_2474.csv',
#  'database_cello_20_peaks_youtube_4140.csv',
#  'database_cello_20_peaks_youtube_3833.csv',
#  'database_cello_20_peaks_youtube_157.csv',
#  'database_cello_20_peaks_youtube_4003.csv',
#  'database_cello_20_peaks_youtube_3916.csv',
#  'database_cello_20_peaks_youtube_282.csv',
#  'database_cello_20_peaks_youtube_4904.csv',
#  'database_cello_20_peaks_youtube_3591.csv',
#  'database_cello_20_peaks_youtube_2575.csv',
#  'database_cello_20_peaks_youtube_3554.csv',
#  'database_cello_20_peaks_youtube_1038.csv',
#  'database_cello_20_peaks_youtube_3228.csv',
#  'database_cello_20_peaks_youtube_3927.csv',
#  'database_cello_20_peaks_youtube_2609.csv',
#  'database_cello_20_peaks_youtube_2394.csv',
#  'database_cello_20_peaks_youtube_310.csv',
#  'database_cello_20_peaks_youtube_789.csv',
#  'database_cello_20_peaks_youtube_1085.csv',
#  'database_cello_20_peaks_youtube_4332.csv',
#  'database_cello_20_peaks_youtube_2754.csv',
#  'database_cello_20_peaks_youtube_2864.csv',
#  'database_cello_20_peaks_youtube_4774.csv',
#  'database_cello_20_peaks_youtube_2332.csv',
#  'database_cello_20_peaks_youtube_2099.csv',
#  'database_cello_20_peaks_youtube_2447.csv',
#  'database_cello_20_peaks_youtube_4733.csv',
#  'database_cello_20_peaks_youtube_4567.csv',
#  'database_cello_20_peaks_youtube_2868.csv',
#  'database_cello_20_peaks_youtube_1165.csv',
#  'database_cello_20_peaks_youtube_2969.csv',
#  'database_cello_20_peaks_youtube_4764.csv',
#  'database_cello_20_peaks_youtube_2281.csv',
#  'database_cello_20_peaks_youtube_1451.csv',
#  'database_cello_20_peaks_youtube_1698.csv',
#  'database_cello_20_peaks_youtube_420.csv',
#  'database_cello_20_peaks_youtube_4485.csv',
#  'database_cello_20_peaks_youtube_4793.csv',
#  'database_cello_20_peaks_youtube_3146.csv',
#  'database_cello_20_peaks_youtube_2905.csv',
#  'database_cello_20_peaks_youtube_1087.csv',
#  'database_cello_20_peaks_youtube_1579.csv',
#  'database_cello_20_peaks_youtube_2139.csv',
#  'database_cello_20_peaks_youtube_2249.csv',
#  'database_cello_20_peaks_youtube_802.csv',
#  'database_cello_20_peaks_youtube_3913.csv',
#  'database_cello_20_peaks_youtube_3791.csv',
#  'database_cello_20_peaks_youtube_2295.csv',
#  'database_cello_20_peaks_youtube_4590.csv',
#  'database_cello_20_peaks_youtube_3478.csv',
#  'database_cello_20_peaks_youtube_4012.csv',
#  'database_cello_20_peaks_youtube_3208.csv',
#  'database_cello_20_peaks_youtube_1850.csv',
#  'database_cello_20_peaks_youtube_1453.csv',
#  'database_cello_20_peaks_youtube_3265.csv',
#  'database_cello_20_peaks_youtube_1330.csv',
#  'database_cello_20_peaks_youtube_1935.csv',
#  'database_cello_20_peaks_youtube_1285.csv',
#  'database_cello_20_peaks_youtube_1026.csv',
#  'database_cello_20_peaks_youtube_4779.csv',
#  'database_cello_20_peaks_youtube_2146.csv',
#  'database_cello_20_peaks_youtube_3299.csv',
#  'database_cello_20_peaks_youtube_2119.csv',
#  'database_cello_20_peaks_youtube_1847.csv',
#  'database_cello_20_peaks_youtube_752.csv',
#  'database_cello_20_peaks_youtube_1206.csv',
#  'database_cello_20_peaks_youtube_2549.csv',
#  'database_cello_20_peaks_youtube_4602.csv',
#  'database_cello_20_peaks_youtube_2441.csv',
#  'database_cello_20_peaks_youtube_4726.csv',
#  'database_cello_20_peaks_youtube_4507.csv',
#  'database_cello_20_peaks_youtube_4929.csv',
#  'database_cello_20_peaks_youtube_428.csv',
#  'database_cello_20_peaks_youtube_4776.csv',
#  'database_cello_20_peaks_youtube_3149.csv',
#  'database_cello_20_peaks_youtube_4303.csv',
#  'database_cello_20_peaks_youtube_592.csv',
#  'database_cello_20_peaks_youtube_3416.csv',
#  'database_cello_20_peaks_youtube_2317.csv',
#  'database_cello_20_peaks_youtube_1214.csv',
#  'database_cello_20_peaks_youtube_4959.csv',
#  'database_cello_20_peaks_youtube_1167.csv',
#  'database_cello_20_peaks_youtube_19.csv',
#  'database_cello_20_peaks_youtube_2298.csv',
#  'database_cello_20_peaks_youtube_3620.csv',
#  'database_cello_20_peaks_youtube_4056.csv',
#  'database_cello_20_peaks_youtube_709.csv',
#  'database_cello_20_peaks_youtube_3327.csv',
#  'database_cello_20_peaks_youtube_2604.csv',
#  'database_cello_20_peaks_youtube_1917.csv',
#  'database_cello_20_peaks_youtube_4924.csv',
#  'database_cello_20_peaks_youtube_3307.csv',
#  'database_cello_20_peaks_youtube_2637.csv',
#  'database_cello_20_peaks_youtube_2476.csv',
#  'database_cello_20_peaks_youtube_4710.csv',
#  'database_cello_20_peaks_youtube_1493.csv',
#  'database_cello_20_peaks_youtube_4229.csv',
#  'database_cello_20_peaks_youtube_2259.csv',
#  'database_cello_20_peaks_youtube_2356.csv',
#  'database_cello_20_peaks_youtube_399.csv',
#  'database_cello_20_peaks_youtube_4391.csv',
#  'database_cello_20_peaks_youtube_3781.csv',
#  'database_cello_20_peaks_youtube_3355.csv',
#  'database_cello_20_peaks_youtube_3887.csv',
#  'database_cello_20_peaks_youtube_3490.csv',
#  'database_cello_20_peaks_youtube_4097.csv',
#  'database_cello_20_peaks_youtube_1530.csv',
#  'database_cello_20_peaks_youtube_4009.csv',
#  'database_cello_20_peaks_youtube_4096.csv',
#  'database_cello_20_peaks_youtube_3413.csv',
#  'database_cello_20_peaks_youtube_2768.csv',
#  'database_cello_20_peaks_youtube_3733.csv',
#  'database_cello_20_peaks_youtube_2911.csv',
#  'database_cello_20_peaks_youtube_1679.csv',
#  'database_cello_20_peaks_youtube_1127.csv',
#  'database_cello_20_peaks_youtube_4264.csv',
#  'database_cello_20_peaks_youtube_3224.csv',
#  ...]

# %%
# for data transformation
import numpy as np
# for visualizing the data
import matplotlib.pyplot as plt
# for opening the media file
import scipy.io.wavfile as wavfile

import re
import librosa
import scipy
# for dataframe manipulation
import pandas as pd

# %%
wavo = '/home/jacs/Documents/DataScience/Personal/song_similarity_audio/TinySOL/Brass/Trumpet_C/ordinario/TpC-ord-D4-ff-N-T27u.wav'

# %%
Fs, audio = wavfile.read(wavo)

# %%
#mfccs = librosa.feature.mfcc(y=audio, sr=Fs)
#print(mfccs.shape)

# %%
x, fs = librosa.load(wavo)
#librosa.display.waveplot(x, sr=fs)

# %%
xx= x#[:5*fs]

# %%
mfccs = librosa.feature.mfcc(y=xx, sr=fs)#, norm='ortho')#, n_fft=26)
print(mfccs.shape)
# Out:
# (20, 277)

# %%
spec_cent = librosa.feature.spectral_centroid(y=xx, sr=fs)
spec_bw = librosa.feature.spectral_bandwidth(y=xx, sr=fs)
rolloff = librosa.feature.spectral_rolloff(y=xx, sr=fs)
zcr = librosa.feature.zero_crossing_rate(xx)

# %%
df = pd.DataFrame()
df['zcr']= zcr[0,:]
for i in range(0,mfccs.shape[0]):
    df['mfccs_{}'.format(i)] = mfccs[i,:]

# %%
df2 = pd.DataFrame()

# %%
pd.concat((df,df2), axis=0)
# Out:
#           zcr     mfccs_0     mfccs_1    mfccs_2    mfccs_3    mfccs_4  \
# 0    0.045898 -415.737305  103.069504 -96.804222 -13.656786 -31.861736
# 1    0.082031 -327.369781   18.892117 -81.987610 -15.546417 -40.456570
# 2    0.118652 -309.744781  -54.891197 -76.026184 -14.901216 -39.500477
# 3    0.133301 -297.504089  -78.074951 -71.981659 -18.569004 -40.816177
# 4    0.137695 -299.034637  -82.745804 -65.994614 -16.901001 -41.415508
# ..        ...         ...         ...        ...        ...        ...
# 272  0.152832 -796.389709   21.565575 -34.758026 -11.125467   6.065620
# 273  0.157715 -808.221985   19.470716 -26.210213  -9.750581   6.292814
# 274  0.196777 -820.435120   18.057205 -16.061483 -11.454499   2.950945
# 275  0.228027 -829.653442   14.358193 -10.927940 -12.389891  -0.349897
# 276  0.189941 -838.646423    9.402626  -5.655042  -8.559281  -1.275348
#
#       mfccs_5    mfccs_6    mfccs_7    mfccs_8  ...   mfccs_10  mfccs_11  \
# 0   -0.890457 -15.117619  -2.563357  -9.672328  ... -14.105756 -2.300482
# 1   -3.576094 -19.789429  -6.321371 -16.689241  ... -16.484398 -8.201829
# 2   -6.333547 -22.837351 -12.566713 -20.797337  ... -18.992548 -9.910611
# 3   -8.901976 -25.291370 -12.014857 -16.229477  ... -16.406181 -7.997846
# 4   -8.783098 -23.976025 -11.450952 -15.494959  ... -16.328541 -7.855775
# ..        ...        ...        ...        ...  ...        ...       ...
# 272 -3.220997  -5.085614  -0.994827   5.779734  ...   2.667820  5.896631
# 273 -5.229931  -8.407425   0.322432   5.094864  ...   1.315611  4.646429
# 274 -1.597087  -6.297444  -0.258820   2.630004  ...   3.303119  6.887836
# 275  2.133152  -2.100560  -2.073977   0.018219  ...   3.854593  6.738873
# 276  2.464921  -0.145063  -1.758593  -0.190170  ...   2.197908  4.669882
#
#       mfccs_12   mfccs_13   mfccs_14   mfccs_15   mfccs_16   mfccs_17  \
# 0   -19.141319 -14.976529 -18.070814 -15.098694 -12.639242 -10.183872
# 1   -19.936331 -17.379805 -19.114517 -13.986477 -14.232728 -10.850560
# 2   -19.737494 -16.770325 -16.687582 -12.140179 -13.895078 -11.682465
# 3   -18.936375 -17.419970 -17.642948 -12.351724 -12.853573  -9.765084
# 4   -18.808596 -16.531498 -15.002306  -8.889341 -10.802452  -8.805325
# ..         ...        ...        ...        ...        ...        ...
# 272   6.319535   3.841958   4.259106   3.184592   0.801211  -0.997854
# 273   6.574253   2.923430   1.490284   2.228259  -0.081041  -1.786340
# 274   4.455142   1.229460   2.275741   2.464656  -0.385067  -2.385700
# 275   5.385349   1.768451   0.543653   1.631713   1.553040  -1.358464
# 276   5.642936   2.661994  -0.409047   0.257599   1.772288   0.251995
#
#       mfccs_18   mfccs_19
# 0    -8.588420  -3.983253
# 1   -13.129425  -6.337300
# 2   -19.687605 -15.796198
# 3   -17.749796 -12.571136
# 4   -16.773270 -12.402907
# ..         ...        ...
# 272  -4.451937 -11.931799
# 273  -4.034853 -11.171613
# 274  -4.377164  -7.337767
# 275  -4.639229  -5.164222
# 276  -2.621543  -3.711043
#
# [277 rows x 21 columns]

# %%
np.mean(mfccs[:,0])
# Out:
# -30.303257

# %%
plt.plot(np.log(xx))
# Out:
# /tmp/ipykernel_25385/4193561038.py:1: RuntimeWarning: invalid value encountered in log
#   plt.plot(np.log(xx))

# %%
meano = []

for i in range(0,mfccs.shape[1]):
    meano.append(np.mean(mfccs[:,i]))

# %%
plt.plot(meano)
#    plt.show()
#    plt.xlim(0,50)
#    plt.ylim(-350,-300)

# %%
sp = scipy.fft.fft(xx)
freq = scipy.fft.fftfreq(len(xx),fs)

# %%
plt.plot(freq,sp)
plt.xlim(0,0.00002)
# Out:
# /home/jacs/jorgenv/lib/python3.10/site-packages/matplotlib/cbook/__init__.py:1298: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)
# (0.0, 2e-05)

# %%
plop = len(xx)
plop2= mfccs.shape[1]

print((plop/plop2)/fs)
# Out:
# 0.023178205096719792

# %%
mfccs[:10,:].shape

# %%
librosa.display.specshow(mfccs, sr=fs, x_axis='time')

# %%
mfccs[0]`

# %%
mfccs = sklearn.preprocessing.scale(mfccs, axis=1)
print(mfccs.mean(axis=1))
print(mfccs.var(axis=1))

# %%
flop = 'TOP_10_MOST_POPULAR_TRUMPET_SONGS_(with_Sheet_Music_Notes)'

# %%
re.sub('[)!$/(]','',flop)

# %%
Fs, audio = wavfile.read('The_Most_Beautiful_Trumpet_Solo.wav')

# %%
#top_2_idx = np.argsort(sp)[-40:]
#listo_freq = [freq[i] for i in top_2_idx]

# %%
# Creates different chunks of data from a signal
# Includes half the past chunk
# Say, you have a 1s signal, you want windows of 0.25s 
# with this methodology you will have each window that includes half of the past window

def chunks(xs, n):
    # xs: signal
    # n: times you want to split the signal
    # len(return): n(even): 2n - 1
    #            : n(odd): 2n +1
    ms = int(len(xs)/n)
    return list(xs[i-int(ms/2):i+int(ms/2)] for i in range(int(ms/2), len(xs), int(ms/2)))
#    return list(xs[i:i+ms] for i in range(0, len(xs), ms))

# %%
def suma_repetidos(freq_int, sp):
    sp_int = []
    frequ_int = []
    for i in range(1,len(freq_int)):
        frequ = int(freq_int[i-1])
        frequ_1 = int(freq_int[i])
        try:
            frequ_2 = int(freq_int[i+1])
        except:
            frequ_2 = int(freq_int[-1])
        if i == 1:
            frequ_int.append(frequ)
        if frequ == frequ_1:
            try:
                sp_new = sp_int[-1] + sp[i+1]
                sp_int.pop()
                sp_int.append(sp_new)
#                print("blop")
            except:
                sp_new = sp[i] + sp[i+1]
                sp_int.append(sp_new)
#                print("blopo")
            if frequ_int[-1] != frequ_1:
                frequ_int.append(frequ_1)
        else:
            sp_new = sp[i]
            sp_int.append(sp_new)
            frequ_int.append(frequ_1)
#            print("plopo")
    return frequ_int, sp_int

# %%
def exist_or_zero(freq_new,sp,freq_final):
    sp_final = []
    maxxo = max(sp)
    for freq in freq_final:
        if freq in freq_new:
            spe = sp[list(freq_new).index(freq)]
            sp_final.append(spe/maxxo)
        else:
            sp_final.append(0)
    return sp_final

# %%
def extract_peaks_and_freqs(aud, Fs):
    sp = scipy.fft.fft(aud)
    freq = scipy.fft.fftfreq(len(aud),Fs)
    freq_sci= scipy.signal.find_peaks(sp)[0]
    sp_sci = scipy.signal.peak_prominences(sp, peaks=freq_sci)[0]
    freq_gaps = np.arange(0,6750,1)
    sp_final = exist_or_zero(freq_sci, sp_sci, freq_gaps)
    freq_final, _ = scipy.signal.find_peaks(sp_final)
    pikos = [sp_final[freq_final[i]] for i in range(0,len(freq_final))]
    sp_sorted = sorted(pikos, reverse= True)
    freq_sorted=[freq_final[pikos.index(pikoso)] for pikoso in sp_sorted]
    return sp_sorted, freq_sorted, sp_final, freq_final

# %%
def final_data_collection(freq_sorted, pikos_sorted, n, m, note_played):
    df_final = pd.DataFrame({'peak_1': [], 'peak_2': [], 'Magnitude difference': [],'instrument': m, 'note_played': []})
    frequs_sp = []
    for i in range(0,len(freq_sorted[:n])):
        freq_1, sp_1 = freq_sorted[i], pikos_sorted[i]
        frequs_sp.append((freq_1, sp_1))
        for j in range(0,len(freq_sorted[:n])):
            freq_2, sp_2 = freq_sorted[j], pikos_sorted[j]
            if (freq_2, sp_2) in frequs_sp:
                continue
            else:
                distance = np.sqrt((freq_2 - freq_1)**2 + (sp_2 - sp_1)**2)
                df_iteration = pd.DataFrame({'peak_1':[(freq_1, sp_1)], 'peak_2':[(freq_2, sp_2)], 'Magnitude difference': [distance] ,'instrument': 1, 'note_played': [note_played]})
                df_final = df_final.append(df_iteration)
    return df_final

# %%
common_path = '/home/jacs/Documents/DataScience/Personal/song_similarity_audio/TinySOL/'
df_into = pd.read_csv(common_path+'TinySOL_metadata.csv')
df_into= df_into[df_into['Needed digital retuning']]
instruments = df_into['Instrument (in full)'].unique()

# %%
instruments

# %%
instruments_test = ['Trombone', 'Trumpet in C']
outputs = ['database_trombone_10_peaks', 'database_trumpet_10_peaks']

# %%
#audio_files = ['A-sharp-trumpet', 'B-trumpet', 'C-sharp-trumpet', 'D-sharp-trumpet', 'E-trumpet', 'F-sharp-trumpet', 'G-sharp-trumpet']

df_final = pd.DataFrame({'peak_1': [], 'peak_2': [], 'Magnitude difference': [],'instrument': [], 'note_played': []})

i=0

for woko in df_into[df_into['Instrument (in full)'] == 'Trumpet in C']['Path']:
    wavo = common_path + woko
    titulo = woko.split('/')[-1]
#    file_1 = file.format(audio_1)
#    wavo = path + file_1
    Fs, audio = wavfile.read(wavo)
    length = audio.shape[0] / Fs
    audio_chunks = chunks(audio,int(length)*2)
    print(f"length = {length}s")
    for aud in audio_chunks[2:-2]:
        length_2 = aud.shape[0] / Fs
#        print(Fs)
        # select left channel only
        try:
            aud = aud[:,0]
            print('plop')
        except:
            aud = aud[:]
            print('anti-plop')
        pikos_sorted, freq_sorted, sp_final, peaks  = extract_peaks_and_freqs(aud, Fs)
        print(i)
        i+=1
        df_final_2 = final_data_collection(freq_sorted, pikos_sorted, 10, 1, titulo).reset_index(drop=True)
        df_final = df_final.append(df_final_2).reset_index(drop=True)
df_final=df_final.reset_index(drop=True)
df_final.to_csv(output[1]+'.csv', index=False)
#################################
#        plt.specgram(aud, Fs=Fs)
#        plt.xticks(time_cnk)    
#        plt.ylim(0,5000)
#        plt.title(titulo)
#        plt.show()
#        time = np.linspace(0., length_2, aud.shape[0])
#        plt.plot(time, aud)
#        plt.title('Original signal')
#        plt.show()
#        plt.plot(peaks, [sp_final[i] for i in peaks])
#        plt.plot(freq_sorted[:10], pikos_sorted[:10],'x')
#        plt.title('Final frequencies and intensities')
#        plt.show()
#        ss = np.fft.ifft(sp_final)
#        time = np.linspace(0., length_2, len(sp_final))
#        plt.plot(time, ss)
#        plt.title('Reconstruccion with data manipulation')
#        plt.show()
#################################

# %%
df_final

# %%
df_final=df_final.reset_index(drop=True)

# %%
df_final.to_csv('database_trumpet_10_peaks.csv', index=False)

# %%
pd.read_csv('database_trumpet_freq.csv')

# %%
max(freq_sci)

# %%
wavfile.write("example.wav", Fs, ss.astype(np.int16))

# %%
sp = scipy.fft.fft(aud)
freq = scipy.fft.fftfreq(len(aud),Fs)
freq_sci= scipy.signal.find_peaks(sp)[0]
sp_sci = scipy.signal.peak_prominences(sp, peaks=freq_sci)[0]
freq_gaps = np.arange(0,6750,1)
sp_final = exist_or_zero(freq_sci, sp_sci, freq_gaps)
freq_final, _ = scipy.signal.find_peaks(sp_final)
pikos = [sp_final[freq_final[i]] for i in range(0,len(freq_final))]
sp_sorted = sorted(pikos, reverse= True)
freq_sorted=[freq_final[pikos.index(pikoso)] for pikoso in sp_sorted]

# %%
plt.plot(freq_gaps, sp_final)
plt.plot(freq_sorted[:15],sp_sorted[:15], 'x')

# %% [markdown]
# # Usando numpy

# %%
#audio_files = ['A-sharp-trumpet', 'B-trumpet', 'C-sharp-trumpet', 'D-sharp-trumpet', 'E-trumpet', 'F-sharp-trumpet', 'G-sharp-trumpet']

df_final = pd.DataFrame({'note_played':[], 'frequencies':[], 'intensities':[], 'instrument': []})

for audio_1 in audio_files:
    file_1 = file.format(audio_1)
    wavo = path + file_1
    Fs, audio = wavfile.read(wavo + '.wav')
    length = audio.shape[0] / Fs
    audio_chunks = chunks(audio,int(length)*2)
    print(f"length = {length}s")
    for aud in audio_chunks[2:-2]:
#        print(Fs)
        # select left channel only
        try:
            aud = aud[:,0]
            print('plop')
        except:
            aud = aud[:]
            print('anti-plop')
        # trim the first 125 seconds
        sp_final = np.fft.fft(aud)
        freq_final = np.fft.fftfreq(aud.shape[-1], d=(1/Fs))
        plt.specgram(aud, Fs=Fs)
        plt.ylim(0,5000)
        time = np.linspace(0., length, aud.shape[0])
        freq_positive = [(freq_final[i], sp_final[i]) for i in range(0,len(freq_final)) if freq_final[i]>=0]
        freq_final = [freq_positive[i][0] for i in range(0,len(freq_positive))]
        sp_final = [freq_positive[i][1] for i in range(0,len(freq_positive))]
        plt.title(file_1)
        plt.show()
        plt.plot(time, aud)
        plt.title('Original signal')
        plt.show()
        plt.plot(freq_final,sp_final)
        plt.title('Final frequencies and intensities')
        plt.show()
        ss = np.fft.ifft(sp_final)
        time = np.linspace(0., length, len(sp_final))
        plt.plot(time, ss)
        plt.title('Reconstruccion with data manipulation')
        plt.show()
        df_iteration = pd.DataFrame({'note_played': file_1, 'frequencies':[freq_final], 'intensities':[sp_final], 'instrument': 1})
        df_final = df_final.append(df_iteration)

# %%
df_final

# %% [markdown]
# # Usando spectrogram de matplotlib

# %%
for audio in audio_files:
    file_1 = file.format(audio_1)
    wavo = path + file_1
    Fs, audio = wavfile.read(wavo + '.wav')
    length = audio.shape[0] / Fs
    audio_chunks = chunks(audio,int(length*8))
    print(f"length = {length}s")
    for aud in audio_chunks[1:-1]:
        # select left channel only
        try:
            aud = aud[:,0]
            print('plop')
        except:
            aud = aud[:]
            print('anti-plop')
        # trim the first 125 seconds
        length = aud.shape[0] / Fs
        first = aud[:int(Fs*length)]
        powerSpectrum, frequenciesFound, time2, imageAxis = plt.specgram(first, Fs=Fs)
        plt.ylim(0,5000)
        time = np.linspace(0., length, aud.shape[0])
        plt.title(file_1)
        plt.show()
        plt.plot(time, aud)
        plt.show()
        print(frequenciesFound)
    #    poweroso = [np.average(powerSpectrum[i,:]) for i in range(0,len(powerSpectrum))]
    #    print(len(poweroso))
    #    ss = np.fft.ifft(poweroso)
        plt.plot(frequenciesFound,powerSpectrum)
        plt.xlim(0,2500)
        plt.title('frequencies')
        plt.show()
    #    plt.plot(ss.real)
    #    plt.title('Reconstruccion')
    #    plt.show()
    #    plt.savefig('{}.png'.format(audio))

# %%
len(frequenciesFound)

# %%
powerSpectrum
