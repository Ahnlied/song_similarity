# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import scipy

# %%
blop = pd.read_csv('Binks_no_sake_spanish_melodic.csv')
to_plot = blop['melodic_contour']

plt.plot(to_plot, '.')

# %%
blop_1 = pd.read_csv('Binks_no_sake_japanese_melodic.csv')
to_plot1 = blop_1['melodic_contour']

plt.plot(to_plot1, '.')

# %%
blop_1 = pd.read_csv('Peaches_melodic.csv')
to_plot1 = blop_1['melodic_contour']

plt.plot(to_plot1, '.')

# %%
blop = pd.read_csv('Crying_in_the_rain_melodic.csv')
to_plot = blop['melodic_contour']

plt.plot(to_plot, '.')

# %%
blop = pd.read_csv('El_Castigo_melodic.csv')
to_plot2 = blop['melodic_contour']

plt.plot(to_plot2, '.')

# %%
scipy.signal.correlate(to_plot1,to_plot)
# Out:
# array([ 6, 14, 22, ..., 18, 22, 15])

# %%
len(to_plot1)
# Out:
# 666

# %%
from fastdtw import fastdtw

a = [0, 1, 2, 3, 4, 3, 2]
b = [0, 1, 2, 3, 4, 3, 2]
d, path = fastdtw(to_plot, to_plot1)
#d, path = fastdtw(a,b)

# %%
d
# Out:
# 352.0
